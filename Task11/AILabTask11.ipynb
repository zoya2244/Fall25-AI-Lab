# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pickle
import numpy as np

# %%
df = pd.read_csv("small_weather_dataset.csv")
df.head(3)
# Out:
#        DATE  MONTH  BASEL_temp_mean  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1              2.9            0.89          1.0286
# 1  20000102      1              3.6            0.87          1.0318
# 2  20000103      1              2.2            0.81          1.0314
#
#    BASEL_precipitation  BASEL_sunshine  RainTomorrow
# 0                 0.03             0.0             1
# 1                 0.00             0.0             1
# 2                 0.00             3.7             0

# %%
df.tail(3)
# Out:
#          DATE  MONTH  BASEL_temp_mean  BASEL_humidity  BASEL_pressure  \
# 197  20000716      7             12.7            0.81          1.0166
# 198  20000717      7             14.8            0.71          1.0192
# 199  20000718      7             16.7            0.66          1.0191
#
#      BASEL_precipitation  BASEL_sunshine  RainTomorrow
# 197                 1.17             2.6             1
# 198                 0.00            12.0             0
# 199                 0.00            11.8             0

# %%
df.columns
# Out:
# Index(['DATE', 'MONTH', 'BASEL_temp_mean', 'BASEL_humidity', 'BASEL_pressure',
#        'BASEL_precipitation', 'BASEL_sunshine', 'RainTomorrow'],
#       dtype='object')

# %%
df.count()
# Out:
# DATE                   200
# MONTH                  200
# BASEL_temp_mean        200
# BASEL_humidity         200
# BASEL_pressure         200
# BASEL_precipitation    200
# BASEL_sunshine         200
# RainTomorrow           200
# dtype: int64

# %%
df.describe()
# Out:
#                DATE       MONTH  BASEL_temp_mean  BASEL_humidity  \
# count  2.000000e+02  200.000000       200.000000       200.00000
# mean   2.000040e+07    3.815000        10.879500         0.70780
# std    1.910765e+02    1.918116         6.723037         0.09375
# min    2.000010e+07    1.000000        -6.800000         0.48000
# 25%    2.000022e+07    2.000000         5.600000         0.64000
# 50%    2.000041e+07    4.000000        10.400000         0.71000
# 75%    2.000053e+07    5.000000        16.700000         0.78000
# max    2.000072e+07    7.000000        25.100000         0.91000
#
#        BASEL_pressure  BASEL_precipitation  BASEL_sunshine  RainTomorrow
# count      200.000000           200.000000      200.000000    200.000000
# mean         1.019582             0.196250        5.113500      0.300000
# std          0.008688             0.415236        4.677882      0.459408
# min          0.992000             0.000000        0.000000      0.000000
# 25%          1.014150             0.000000        0.400000      0.000000
# 50%          1.019150             0.000000        3.900000      0.000000
# 75%          1.026025             0.250000        8.800000      1.000000
# max          1.039100             4.110000       15.300000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE                 200 non-null    int64
#  1   MONTH                200 non-null    int64
#  2   BASEL_temp_mean      200 non-null    float64
#  3   BASEL_humidity       200 non-null    float64
#  4   BASEL_pressure       200 non-null    float64
#  5   BASEL_precipitation  200 non-null    float64
#  6   BASEL_sunshine       200 non-null    float64
#  7   RainTomorrow         200 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 12.6 KB

# %%
df.shape
print(f"Number of Rows: {df.shape[0]} and Number of Columns: {df.shape[1]}")
# Out:
# Number of Rows: 200 and Number of Columns: 8

# %%
df['MONTH'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7], dtype=int64)

# %%
df.nunique()
# Out:
# DATE                   200
# MONTH                    7
# BASEL_temp_mean        138
# BASEL_humidity          41
# BASEL_pressure         151
# BASEL_precipitation     60
# BASEL_sunshine          91
# RainTomorrow             2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# DATE                   0
# MONTH                  0
# BASEL_temp_mean        0
# BASEL_humidity         0
# BASEL_pressure         0
# BASEL_precipitation    0
# BASEL_sunshine         0
# RainTomorrow           0
# dtype: int64

# %% [markdown]
# ## Data Pre-Processing

# %%
df = df.drop('MONTH', axis=1)

# %%
df = df.drop('BASEL_temp_mean', axis=1)

# %%
def fillnaObjectMode(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mode()[0])

columns = ['BASEL_pressure', 'BASEL_temp_mean']
fillnaObjectMode(columns)

# %%
def fillnaIntMode(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mode()[0])

columns = ['MONTH','BASEL_temp_mean','BASEL_humidity','BASEL_pressure','BASEL_precipitation','BASEL_sunshine','RainTomorrow']
fillnaIntMode(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE                 200 non-null    int64
#  1   MONTH                200 non-null    int64
#  2   BASEL_temp_mean      200 non-null    float64
#  3   BASEL_humidity       200 non-null    float64
#  4   BASEL_pressure       200 non-null    float64
#  5   BASEL_precipitation  200 non-null    float64
#  6   BASEL_sunshine       200 non-null    float64
#  7   RainTomorrow         200 non-null    int64
# dtypes: float64(5), int64(3)
# memory usage: 12.6 KB

# %% [markdown]
# ## Manage Data Types

# %%
df['BASEL_humidity'] = df['BASEL_humidity'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE                 200 non-null    int64
#  1   MONTH                200 non-null    int64
#  2   BASEL_temp_mean      200 non-null    float64
#  3   BASEL_humidity       200 non-null    int64
#  4   BASEL_pressure       200 non-null    float64
#  5   BASEL_precipitation  200 non-null    float64
#  6   BASEL_sunshine       200 non-null    float64
#  7   RainTomorrow         200 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 12.6 KB

# %%
def convertObjToInt(cols):
    for i in cols:
        data = pd.DataFrame({i:df[i].unique()})
        data_LE = LabelEncoder()
        data_LE.fit(np.ravel(data))    
        df[i] = data_LE.transform(df[i])
        
columns = ['BASEL_precipitation', 'BASEL_humidity', 'BASEL_pressure']
convertObjToInt(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE                 200 non-null    int64
#  1   MONTH                200 non-null    int64
#  2   BASEL_temp_mean      200 non-null    float64
#  3   BASEL_humidity       200 non-null    int64
#  4   BASEL_pressure       200 non-null    float64
#  5   BASEL_precipitation  200 non-null    float64
#  6   BASEL_sunshine       200 non-null    float64
#  7   RainTomorrow         200 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 12.6 KB

# %%
df.head(3)
# Out:
#        DATE  MONTH  BASEL_temp_mean  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1              2.9               0          1.0286
# 1  20000102      1              3.6               0          1.0318
# 2  20000103      1              2.2               0          1.0314
#
#    BASEL_precipitation  BASEL_sunshine  RainTomorrow
# 0                 0.03             0.0             1
# 1                 0.00             0.0             1
# 2                 0.00             3.7             0

# %%
df.to_csv('processed_data.csv', index=False, header=True)

# %%
df = pd.read_csv('processed_data.csv')
df
# Out:
#          DATE  MONTH  BASEL_temp_mean  BASEL_humidity  BASEL_pressure  \
# 0    20000101      1              2.9               0          1.0286
# 1    20000102      1              3.6               0          1.0318
# 2    20000103      1              2.2               0          1.0314
# 3    20000104      1              3.9               0          1.0262
# 4    20000105      1              6.0               0          1.0246
# ..        ...    ...              ...             ...             ...
# 195  20000714      7             13.7               0          1.0116
# 196  20000715      7             12.6               0          1.0124
# 197  20000716      7             12.7               0          1.0166
# 198  20000717      7             14.8               0          1.0192
# 199  20000718      7             16.7               0          1.0191
#
#      BASEL_precipitation  BASEL_sunshine  RainTomorrow
# 0                   0.03             0.0             1
# 1                   0.00             0.0             1
# 2                   0.00             3.7             0
# 3                   0.35             6.9             1
# 4                   0.07             3.7             1
# ..                   ...             ...           ...
# 195                 1.09             0.1             1
# 196                 0.64             2.4             1
# 197                 1.17             2.6             1
# 198                 0.00            12.0             0
# 199                 0.00            11.8             0
#
# [200 rows x 8 columns]

# %% [markdown]
# ## Train - Test Splitting

# %%
import pandas as pd
df = pd.read_csv('processed_data.csv')
df.columns
# Out:
# Index(['DATE', 'MONTH', 'BASEL_temp_mean', 'BASEL_humidity', 'BASEL_pressure',
#        'BASEL_precipitation', 'BASEL_sunshine', 'RainTomorrow'],
#       dtype='object')

# %%
X = df.drop('BASEL_temp_mean', axis=1)  
y = df['BASEL_temp_mean']

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X,y, test_size=0.3, shuffle=False)

# %%
print(train_X.shape, train_y.shape)
print(test_X.shape, test_y.shape)
# Out:
# (140, 7) (140,)
# (60, 7) (60,)

# %% [markdown]
# ## Applying Classifier / Model Training

# %%
from sklearn.svm import SVC 

model_svc = SVC()
model_svc.fit(train_X, train_y)

print(model_svc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[131], line 4
#       1 from sklearn.svm import SVC
#       3 model_svc = SVC()
# ----> 4 model_svc.fit(train_X, train_y)
#       6 print(model_svc)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:199, in BaseLibSVM.fit(self, X, y, sample_weight)
#     189 else:
#     190     X, y = self._validate_data(
#     191         X,
#     192         y,
#    (...)
#     196         accept_large_sparse=False,
#     197     )
# --> 199 y = self._validate_targets(y)
#     201 sample_weight = np.asarray(
#     202     [] if sample_weight is None else sample_weight, dtype=np.float64
#     203 )
#     204 solver_type = LIBSVM_IMPL.index(self._impl)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:739, in BaseSVC._validate_targets(self, y)
#     737 def _validate_targets(self, y):
#     738     y_ = column_or_1d(y, warn=True)
# --> 739     check_classification_targets(y)
#     740     cls, y = np.unique(y_, return_inverse=True)
#     741     self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\multiclass.py:221, in check_classification_targets(y)
#     213 y_type = type_of_target(y, input_name="y")
#     214 if y_type not in [
#     215     "binary",
#     216     "multiclass",
#    (...)
#     219     "multilabel-sequences",
#     220 ]:
# --> 221     raise ValueError(
#     222         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     223         "classifier, which expects discrete classes on a "
#     224         "regression target with continuous values."
#     225     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
model_pred_svc = model_svc.predict(test_X)
model_pred_svc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 model_pred_svc = model_svc.predict(test_X)
#       2 model_pred_svc
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:814, in BaseSVC.predict(self, X)
#     812     y = np.argmax(self.decision_function(X), axis=1)
#     813 else:
# --> 814     y = super().predict(X)
#     815 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:429, in BaseLibSVM.predict(self, X)
#     413 def predict(self, X):
#     414     """Perform regression on samples in X.
#     415
#     416     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     427         The predicted values.
#     428     """
# --> 429     X = self._validate_for_predict(X)
#     430     predict = self._sparse_predict if self._sparse else self._dense_predict
#     431     return predict(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\svm\_base.py:636, in BaseLibSVM._validate_for_predict(self, X)
#     629         raise ValueError(
#     630             "X.shape[1] = %d should be equal to %d, "
#     631             "the number of samples at training time"
#     632             % (X.shape[1], self.shape_fit_[0])
#     633         )
#     634 # Fixes https://nvd.nist.gov/vuln/detail/CVE-2020-28975
#     635 # Check that _n_support is consistent with support_vectors
# --> 636 sv = self.support_vectors_
#     637 if not self._sparse and sv.size > 0 and self.n_support_.sum() != sv.shape[0]:
#     638     raise ValueError(
#     639         f"The internal representation of {self.__class__.__name__} was altered"
#     640     )
#
# AttributeError: 'SVC' object has no attribute 'support_vectors_'

# %%
from sklearn.metrics import accuracy_score
model_acc_svc = accuracy_score(test_y, model_pred_svc)
print(round(model_acc_svc,3)*100, "%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[136], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 model_acc_svc = accuracy_score(test_y, model_pred_svc)
#       3 print(round(model_acc_svc,3)*100, "%")
#
# NameError: name 'model_pred_svc' is not defined

# %%
import pickle
pickle.dump(model_svc, open('model_svc.pkl', 'wb'))

# %%
import pickle
model_svc = pickle.load(open('model_svc.pkl', 'rb'))
